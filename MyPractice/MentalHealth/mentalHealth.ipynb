# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
df = pd.read_csv("mental-illnesses-prevalence.csv")
df.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                           0.223206
# 1                                           0.222454
# 2                                           0.221751
# 3                                           0.220987
# 4                                           0.220183
#
#    Depressive disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                           4.996118
# 1                                           4.989290
# 2                                           4.981346
# 3                                           4.976958
# 4                                           4.977782
#
#    Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized  \
# ...

# %%
df.shape
# Out:
# (6420, 8)

# %%
columns = df.columns.values
#print(columns)
type(columns)
#strip and remove anything in parentheses from the column names
df.columns = [str(item).split("(")[0].strip() for item in df.columns]
print(df.columns)
# Out:
# Index(['Entity', 'Code', 'Year', 'Schizophrenia disorders',
#        'Depressive disorders', 'Anxiety disorders', 'Bipolar disorders',
#        'Eating disorders'],
#       dtype='object')

# %%
sns.histplot(df['Bipolar disorders'])
# Out:
# <Axes: xlabel='Bipolar disorders', ylabel='Count'>

# %%
sns.scatterplot(x='Entity', y='Bipolar disorders', data=df)
# Out:
# <Axes: xlabel='Entity', ylabel='Bipolar disorders'>
